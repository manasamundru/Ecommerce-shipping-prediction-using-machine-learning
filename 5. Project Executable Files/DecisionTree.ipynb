# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
data=pd.read_csv("train.csv")
data
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
print(data.shape)
# Out:
# (10999, 12)

# %%
data.describe()
# Out:
#                 ID  Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count  10999.00000         10999.000000     10999.000000         10999.000000
# mean    5500.00000             4.054459         2.990545           210.196836
# std     3175.28214             1.141490         1.413603            48.063272
# min        1.00000             2.000000         1.000000            96.000000
# 25%     2750.50000             3.000000         2.000000           169.000000
# 50%     5500.00000             4.000000         3.000000           214.000000
# 75%     8249.50000             5.000000         4.000000           251.000000
# max    10999.00000             7.000000         5.000000           310.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# count     10999.000000      10999.000000   10999.000000         10999.000000
# mean          3.567597         13.373216    3634.016729             0.596691
# ...

# %% [markdown]
# # Univirate analysis

# %%
plt.figure(figsize=(20, 25))

# Plotting Count-Plot.
# 1st Plot!
plt.subplot(4,2,1)
plt.gca().set_title('Variable Warehouse Block')
sns.countplot(x = 'Warehouse_block', palette = 'Set3', data = data)
plt.gca().set_xlabel('Warehouse Block')

# 2nd Plot!
plt.subplot(4,2,2)
plt.gca().set_title('Variable Mode of Shipment')
sns.countplot(x = 'Mode_of_Shipment', palette = 'Set3', data = data)
plt.gca().set_xlabel('Mode of Shipment')

# 3rd Plot!
plt.subplot(4,2,3)
plt.gca().set_title('Variable Customer Rating')
sns.countplot(x = 'Customer_rating',palette = 'Set3', data = data)
plt.gca().set_xlabel('Customer Rating')

# 4th Plot!
plt.subplot(4,2,4)
plt.gca().set_title('Variable Product Importance')
sns.countplot(x = 'Product_importance', palette = 'Set3', data = data)
plt.gca().set_xlabel('Product Importance')

# 5th Plot!
plt.subplot(4,2,5)
plt.gca().set_title('Variable Gender')
sns.countplot(x = 'Gender', palette = 'Set3', data = data)
plt.gca().set_xlabel('Gender')
# Out:
# Text(0.5, 0, 'Gender')

# %%
plt.figure(figsize = (25,20))

# Plotting Hist-Plots.
plt.subplot(2, 2, 1)
sns.histplot(data=data.Customer_care_calls, kde=True)
plt.gca().set_xlabel('Customer Care Calls')

plt.subplot(2, 2, 2)
sns.histplot(data=data.Cost_of_the_Product, kde=True)
plt.gca().set_xlabel('Cost of The Product')

plt.subplot(2, 2, 3)
sns.histplot(data=data.Prior_purchases, kde=True)
plt.gca().set_xlabel('Prior Purchases')

plt.subplot(2, 2, 4)
sns.histplot(data=data.Discount_offered, kde=True)
plt.gca().set_xlabel('Discount Offered')
# Out:
# C:\Users\nagas\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nagas\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nagas\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# # Bivarite analysis

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
g = sns.barplot(x='Customer_care_calls',y='Cost_of_the_Product', data=data)
plt.subplot(2,2,2)
g = sns.barplot(x='Customer_care_calls',y='Discount_offered', data=data)
plt.subplot(2,2,3)
g = sns.barplot(x='Reached.on.Time_Y.N',y='Weight_in_gms', data=data)
plt.subplot(2,2,4)
g = sns.barplot(x='Reached.on.Time_Y.N',y='Discount_offered', data=data)

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
g = sns.barplot(x='Reached.on.Time_Y.N',y='Cost_of_the_Product', data=data)
plt.subplot(2,2,2)
g = sns.barplot(x='Gender',y='Discount_offered', data=data)
plt.subplot(2,2,3)
g = sns.barplot(x='Reached.on.Time_Y.N',y='Customer_rating', data=data)
plt.subplot(2,2,4)
g = sns.barplot(x='Reached.on.Time_Y.N',y='Prior_purchases', data=data)

# %%
sns.pairplot(data, corner=True)
# Out:
# C:\Users\nagas\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nagas\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nagas\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
data.isnull().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %% [markdown]
# # Encoding

# %%
le = LabelEncoder()
data['Warehouse_block']=le.fit_transform(data['Warehouse_block'])
data['Mode_of_Shipment']=le.fit_transform(data['Mode_of_Shipment'])
data['Product_importance']=le.fit_transform(data['Product_importance'])
data['Gender']=le.fit_transform(data['Gender'])
data['Reached.on.Time_Y.N']=le.fit_transform(data['Reached.on.Time_Y.N'])

# %%
x=data.drop(columns=["ID","Reached.on.Time_Y.N"])
y=data["Reached.on.Time_Y.N"]
x
# Out:
#        Warehouse_block  Mode_of_Shipment  Customer_care_calls  \
# 0                    3                 0                    4
# 1                    4                 0                    4
# 2                    0                 0                    2
# 3                    1                 0                    3
# 4                    2                 0                    2
# ...                ...               ...                  ...
# 10994                0                 2                    4
# 10995                1                 2                    4
# 10996                2                 2                    5
# 10997                4                 2                    5
# 10998                3                 2                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# 1                    5                  216                2
# ...

# %% [markdown]
# # Multivariate analysis

# %%
hm=data.corr(numeric_only=True)
data
# Out:
#           ID  Warehouse_block  Mode_of_Shipment  Customer_care_calls  \
# 0          1                3                 0                    4
# 1          2                4                 0                    4
# 2          3                0                 0                    2
# 3          4                1                 0                    3
# 4          5                2                 0                    2
# ...      ...              ...               ...                  ...
# 10994  10995                0                 2                    4
# 10995  10996                1                 2                    4
# 10996  10997                2                 2                    5
# 10997  10998                4                 2                    5
# 10998  10999                3                 2                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
hm=data.corr(numeric_only=True)
sns.heatmap(hm)
# Out:
# <Axes: >

# %% [markdown]
# # Scaling

# %%
sc=StandardScaler()
names=x.columns
x=sc.fit_transform(x)
x=pd.DataFrame(x,columns=names)

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,
                                        random_state=1234,test_size = 0.20,
                                        shuffle=True
                                        )
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8799, 10)
# (2200, 10)
# (8799,)
# (2200,)

# %%
from sklearn.ensemble import RandomForestClassifier as skrfc
from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, r2_score, mean_squared_error, mean_absolute_error, f1_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import cross_validate, GridSearchCV, RandomizedSearchCV
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeClassifier

# %%
# Train and Build the model using DecisionTreeClassifier
def decision_tree_model(x_train,y_train,x_test,y_test):
    df=make_pipeline(StandardScaler(),DecisionTreeClassifier(criterion='entropy',random_state=1))
    df.fit(x_train,y_train)
    print('--DecisionTreeClassifier')
    print('Train Score:',df.score(x_train,y_train))
    print('Test Score:',df.score(x_test,y_test))
    print()
    return df

# %%
df=decision_tree_model(x_train,y_train,x_test,y_test)
pred=df.predict(x_test)
print(pred) # predicted values
print(y_test) # actual values
accuracy=accuracy_score(y_test,pred)
print()
# Printing Accuracy Scorce of DecisionTreeClassifier model
print("accuracy score of DecisionTreeClassifier model is:",accuracy)
# Out:
# --DecisionTreeClassifier
# Train Score: 1.0
# Test Score: 0.6468181818181818
#
# [0 1 0 ... 1 0 0]
# 7212    1
# 7220    0
# 4637    1
# 2709    1
# 8161    0
#        ..
# 1628    1
# 901     1
# 8903    0
# 7018    1
# 8349    1
# Name: Reached.on.Time_Y.N, Length: 2200, dtype: int64
#
# accuracy score of DecisionTreeClassifier model is: 0.6468181818181818

# %%
# Printing classification report of DecisionTreeClassifier model
print("classification report of DecisionTreeClassifier model: ")
print(classification_report(y_test,pred))
# Out:
# classification report of DecisionTreeClassifier model:
#               precision    recall  f1-score   support
#
#            0       0.56      0.58      0.57       896
#            1       0.71      0.69      0.70      1304
#
#     accuracy                           0.65      2200
#    macro avg       0.64      0.64      0.64      2200
# weighted avg       0.65      0.65      0.65      2200

# %%
# Printing confusion matrix of DecisionTreeClassifier model
print("confusion matrix of DecisionTreeClassifier model:")
print(confusion_matrix(y_test,pred))
# Out:
# confusion matrix of DecisionTreeClassifier model:
# [[524 372]
#  [405 899]]
